# %% [markdown]
# <a href="https://colab.research.google.com/github/punith2603/AI-ML/blob/main/AI_ML_exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
yield_Apples=[0.85,0.91,0.919,0.926,0.929,0.931]

# %%
plt.plot(yield_Apples)

# %%
years=[2010,2011,2012,2013,2014,2015]
yield_Apples=[0.85,0.91,0.919,0.926,0.929,0.931]
plt.plot(years,yield_Apples)

# %%
plt.plot(years,yield_Apples)
plt.xlabel('year')
plt.ylabel('yield(tons per hectare)');

# %%
year=range(2000,2008)
apples=[0.895,0.91,0.919,0.926,0.929,0.934,0.936,0.937]
oranges=[0.962,0.941,0.930,0.918,0.908,0.907,0.904,0.901]
plt.plot(year,apples)
plt.plot(year,oranges)
plt.xlabel('year')
plt.ylabel('yield')
# Out:
# Text(0, 0.5, 'yield')

# %%
year=range(2000,2008)
apples=[0.895,0.91,0.919,0.926,0.929,0.934,0.936,0.937]
oranges=[0.962,0.941,0.930,0.918,0.908,0.907,0.904,0.901]
plt.plot(year,apples)
plt.plot(year,oranges)
plt.xlabel('year')
plt.ylabel('yield')
plt.title('crop yields in kanto')
plt.legend(['Apples','Oranges'])

# %%
plt.plot(year,apples,marker='o')
plt.plot(year,oranges,marker='x')
plt.ylabel('yield')
plt.title('crop yields in kanto')
plt.legend(['Apples','Oranges']);

# %%
plt.plot(year,apples,marker='s',c='b',ls='-',lw=2,ms=8,mew=2,mec='navy')
plt.plot(year,oranges,marker='o',c='r',ls='--',lw=3,ms=10,alpha=0.5)
plt.xlabel('years')
plt.ylabel('yield')
plt.title('crop yield in kanto')
plt.legend(['Apples','Oranges'])

# %%
plt.plot(year,apples,"s-b")
plt.plot(year,oranges,'o--r')
plt.xlabel('year')
plt.ylabel('yield')
plt.title('crop yiels in kanto')
plt.legend(['apples','oranges'])

# %%
plt.plot(year,oranges,'or')
plt.title('yield of oranges')
# Out:
# Text(0.5, 1.0, 'yield of oranges')

# %%
plt.figure(figsize=(4,4))
plt.plot(year,oranges,'or')
plt.title('yield of oranges')
# Out:
# Text(0.5, 1.0, 'yield of oranges')

# %%
x=[3,1,3,12,2,4,4]
y=[3,2,1,4,5,6,7]
plt.bar(x,y)
plt.title("bar chart")
plt.legend(["bar"])
plt.show()

# %%
x=[3,1,3,12,2,4,4]
y=[3,2,1,4,5,6,7]
plt.scatter(x,y)
plt.legend("A")
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
x=[1,2,3,4]
e=(0.1,0,0,0)
plt.pie(x,explode=e)
plt.title("pie chart")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df=pd.read_csv('/content/advertising.csv')
df.head(10)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   15.6

# %%
x=df['TV']
y=df['Sales']
plt.scanner(x,y,color='blue',label='scatter plot')
plt.title('relationship between tv and sales')
plt.xlabel('tv')
plt.ylabel('sales')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-1c2c6dad94d1> in <cell line: 3>()
#       1 x=df['TV']
#       2 y=df['Sales']
# ----> 3 plt.scanner(x,y,color='blue',label='scatter plot')
#       4 plt.title('relationship between tv and sales')
#       5 plt.xlabel('tv')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'scanner'

# %%
print(x.shape)
print(y.shape)
# Out:
# (200,)
# (200,)

# %%
x=x.reshape(-1,1)
y=y.reshape(-1,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-c0e5055d4d41> in <cell line: 1>()
# ----> 1 x=x.reshape(-1,1)
#       2 y=y.reshape(-1,1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression

# %%
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,lm.predict(X_train),color='blue')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-18c24d2fe8a8> in <cell line: 1>()
# ----> 1 plt.scatter(X_train,y_train,color='red')
#       2 plt.plot(X_train,lm.predict(X_train),color='blue')
#
# NameError: name 'X_train' is not defined

# %%
slope = lm.coef_
intercept = lm.intercept_  # remove the trailing comma

print("estimated model slope:", slope)
print("estimated model intercept:", intercept)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-05146abc8db4> in <cell line: 1>()
# ----> 1 slope = lm.coef_
#       2 intercept = lm.intercept_  # remove the trailing comma
#       3
#       4 print("estimated model slope:", slope)
#       5 print("estimated model intercept:", intercept)
#
# AttributeError: type object 'LinearRegression' has no attribute 'coef_'
